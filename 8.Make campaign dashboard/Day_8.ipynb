# %%
import pandas as pd
import os

# Create sample OOH campaign data
campaign_data = """city,format,impressions,clicks,cost_eur,revenue_eur,duration_days
Berlin,Billboard,150000,450,2500,5400,30
Berlin,Transit,120000,360,1800,4320,30
Munich,Billboard,100000,250,2000,3750,30
Munich,Digital,80000,320,1200,3840,30
Hamburg,Billboard,90000,180,1800,2700,30
Hamburg,Transit,110000,330,1600,3960,30
Frankfurt,Billboard,120000,360,2400,4320,30
Frankfurt,Digital,95000,380,1400,4560,30"""

# Save to CSV in your working directory
with open('ooh_campaigns.csv', 'w') as f:
    f.write(campaign_data)

print("✅ CSV file created: ooh_campaigns.csv")
# Out:
# ✅ CSV file created: ooh_campaigns.csv

# %%
# Import Pandas
import pandas as pd

# %%
# Read the CSV FILE 
df =pd.read_csv('ooh_campaigns.csv')

# %%
# Display the entire Dataframs
print("Our campaign data:")
print(df)
# Out:
# Our campaign data:
#         city     format  impressions  clicks  cost_eur  revenue_eur  \
# 0     Berlin  Billboard       150000     450      2500         5400
# 1     Berlin    Transit       120000     360      1800         4320
# 2     Munich  Billboard       100000     250      2000         3750
# 3     Munich    Digital        80000     320      1200         3840
# 4    Hamburg  Billboard        90000     180      1800         2700
# 5    Hamburg    Transit       110000     330      1600         3960
# 6  Frankfurt  Billboard       120000     360      2400         4320
# 7  Frankfurt    Digital        95000     380      1400         4560
#
#    duration_days
# 0             30
# 1             30
# 2             30
# 3             30
# 4             30
# 5             30
# 6             30
# 7             30

# %%
# Exploring the data frame displayed above 
# Check the dimensions (Rows & Columns)

print (f"Shape: {df.shape}") 

# Check the column names & data types 

print ("\n Data Types:")
print (df.dtypes)

# See just the first few rows

print ("\nFirst 3 rows:")
print (df.head(3))

# Get summary statistics (min,max,mean)

print("\nBasic Statistcs:")
print(df.describe())
# Out:
# Shape: (8, 7)
#
#  Data Types:
# city             object
# format           object
# impressions       int64
# clicks            int64
# cost_eur          int64
# revenue_eur       int64
# duration_days     int64
# dtype: object
#
# First 3 rows:
#      city     format  impressions  clicks  cost_eur  revenue_eur  \
# 0  Berlin  Billboard       150000     450      2500         5400
# 1  Berlin    Transit       120000     360      1800         4320
# 2  Munich  Billboard       100000     250      2000         3750
#
#    duration_days
# 0             30
# 1             30
# 2             30
#
# Basic Statistcs:
#          impressions     clicks     cost_eur  revenue_eur  duration_days
# count       8.000000    8.00000     8.000000     8.000000            8.0
# mean   108125.000000  328.75000  1837.500000  4106.250000           30.0
# std     22028.796089   82.53787   453.360468   771.620512            0.0
# min     80000.000000  180.00000  1200.000000  2700.000000           30.0
# ...

# %%
# Extract specific columns 
# Get a single column as a series 

cities = df['city']
print("Cities in our data:")
print(cities)

# get mutiple columns as a series 

campaign_data = df[['city', 'format', 'impressions']]
print("\nCampaign Data:")
print(campaign_data)

# Get a specific value 

first_city = df['city'][0] # this will be the first city 

print(f"\nFirst campaign city: {first_city}")
# Out:
# Cities in our data:
# 0       Berlin
# 1       Berlin
# 2       Munich
# 3       Munich
# 4      Hamburg
# 5      Hamburg
# 6    Frankfurt
# 7    Frankfurt
# Name: city, dtype: object
#
# Campaign Data:
#         city     format  impressions
# 0     Berlin  Billboard       150000
# 1     Berlin    Transit       120000
# 2     Munich  Billboard       100000
# 3     Munich    Digital        80000
# 4    Hamburg  Billboard        90000
# 5    Hamburg    Transit       110000
# 6  Frankfurt  Billboard       120000
# 7  Frankfurt    Digital        95000
#
# First campaign city: Berlin

# %%
# CHALLENGE: Without looking below, try to:
# 1. Print the 'revenue_eur' column
Revenue = df['revenue_eur']
print("\nRevenue in Euros:")
print(Revenue)

# 2. Print the last 2 rows of the DataFrame
Last_rows = df . tail (2)
print("\nLast 2 rows of the DataFrame:")
print(Last_rows)

# 3. Print the data type of the 'impressions' column
impressions_data_type = df['impressions'].dtype
print(f"\nData type of 'impressions')")
print (impressions_data_type)


# Write your code here:
# (Hint: use df['column_name'], df.tail(), df.dtypes)
# Out:
# Revenue in Euros:
# 0    5400
# 1    4320
# 2    3750
# 3    3840
# 4    2700
# 5    3960
# 6    4320
# 7    4560
# Name: revenue_eur, dtype: int64
#
# Last 2 rows of the DataFrame:
#         city     format  impressions  clicks  cost_eur  revenue_eur  \
# 6  Frankfurt  Billboard       120000     360      2400         4320
# 7  Frankfurt    Digital        95000     380      1400         4560
#
#    duration_days
# 6             30
# 7             30
#
# Data type of 'impressions')
# int64

# %%
# 1. Stage changes
git add .

# 2. Commit with message
git commit -m "Day 9: Pandas Filtering and Sorting"

# 3. Push to GitHub
git push
# Out:
#   Cell In[25], line 2
#     git add .
#         ^
# SyntaxError: invalid syntax
